# %%
# !pip install PyWavelets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PyWavelets
#   Downloading PyWavelets-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.17.3 in /usr/lib/python3.10/site-packages (from PyWavelets) (1.24.1)
# Installing collected packages: PyWavelets
# Successfully installed PyWavelets-1.4.1

# %%
import numpy as np
import pandas as pd
import mne
import os
import mne_icalabel
import matplotlib.pyplot as plt
from mne import find_events
from glob import glob
from scipy import signal
from scipy.stats import zscore
from mne.preprocessing import ICA
# from mne.preprocessing import AMICA
from sklearn.decomposition import FastICA
from mne_icalabel import label_components
from mpl_toolkits.mplot3d import Axes3D

# %%
os.environ['OMP_NUM_THREADS'] = '4'

# %%
all_file_path = glob('../data-files/sub2/*.set')
print(len(all_file_path))
# Out:
# 12

# %%
os.path.basename(all_file_path[0])[3]
# Out:
# '0'

# %%
rest_files_path = [i for i in all_file_path if 'r' == os.path.basename(i)[3]]
zerob_files_path = [i for i in all_file_path if '0' == os.path.basename(i)[3]]
oneb_files_path = [i for i in all_file_path if '1' == os.path.basename(i)[3]]
twob_files_path = [i for i in all_file_path if '2' == os.path.basename(i)[3]]

print(oneb_files_path)
# Out:
# ['../data-files/sub2/s3-1back.set', '../data-files/sub2/s2-1back.set', '../data-files/sub2/s1-1back.set']

# %%
def readfile(file_path):
    
    # load the EEG data
    eeg = mne.io.read_raw_eeglab(file_path, preload = True)
    
    # drop the 'ECG1' channel
    eeg = eeg.drop_channels(['ECG1'])
    
    # get the task name from the file path
    task = os.path.basename(file_path)[3:]
    
    # specify the event IDs to consider druing epoching for the each task
    included_events = []
    if task == '0back.set':
        included_events = ['6021', '6022']
    elif task == '1back.set':
        included_events = ['6121', '6122']
    elif task == '2back.set':
        included_events = ['6221', '6222']
    
    # include only the specified events in the annotations
    include_annots = included_events
    include_mask = [annot in include_annots for annot in eeg.annotations.description]
    included_annotations = mne.Annotations(onset=eeg.annotations.onset[include_mask], duration=eeg.annotations.duration[include_mask],description=eeg.annotations.description[include_mask])
    eeg.set_annotations(included_annotations)
    
    # extract events from the annotations and exclude any events not considered for epoching
    events, events_id = mne.events_from_annotations(eeg, event_id=None)
    events = events[events[:, 2] <= len(include_annots)]
    event_id = {include_annots[i]: i + 1 for i in range(len(include_annots))}
    
    # rereference the data to the average reference and apply a bandpass filter
    eeg.set_eeg_reference()
    eeg.filter(l_freq=0.5, h_freq=45)
    
    # apply a notch filter to remove line noise
    eeg.notch_filter(freqs=50)
    
    # specify the time window for the epochs
    tmin, tmax = -0.05, 0.7
    
    # create epochs using the extracted events and time window
    if len(events) > 0:
        epochs = mne.Epochs(eeg, events, event_id=event_id, tmin=tmin, tmax=tmax, baseline=(None, 0))
        return epochs
    # if no events were found, create fixed-length epochs, this is required for epoching rest data that does not have any events
    else:
        epochs = mne.make_fixed_length_epochs(eeg, duration=0.752, overlap=0.2)
        return epochs

# %%
data = readfile(all_file_path[0])
data.load_data()
# Out:
# Reading /home/rahul/Drives/Drive-D/clg/BTP-files/codes/../data-files/sub2/s2-0back.fdt
# Reading 0 ... 165516  =      0.000 ...   331.032 secs...
# /tmp/ipykernel_49174/4155547097.py:2: RuntimeWarning: Data file name in EEG.data (zeroBACK.fdt) is incorrect, the file name must have changed on disk, using the correct file name (s2-0back.fdt).
#   eeg = mne.io.read_raw_eeglab(file_path, preload = True)
# Used Annotations descriptions: ['6021', '6022']
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 3301 samples (6.602 sec)
# /tmp/ipykernel_49174/4155547097.py:2: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   eeg = mne.io.read_raw_eeglab(file_path, preload = True)
# /tmp/ipykernel_49174/4155547097.py:2: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   eeg = mne.io.read_raw_eeglab(file_path, preload = True)
# /tmp/ipykernel_49174/4155547097.py:2: RuntimeWarning: Not setting position of 1 ecg channel found in montage:
# ['ECG1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   eeg = mne.io.read_raw_eeglab(file_path, preload = True)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3301 samples (6.602 sec)
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Not setting metadata
# 144 matching events found
# Setting baseline interval to [-0.05, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 144 events and 376 original time points ...
# 0 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:    0.2s finished
# <Epochs |  144 events (all good), -0.05 - 0.7 sec, baseline -0.05 – 0 sec, ~25.7 MB, data loaded,
#  '6021': 96
#  '6022': 48>

# %%
sample_data = data.get_data()

# %%
sample_data.shape    #no. of epochs, no. of channels, length of signal
# Out:
# (144, 62, 376)

# %%
len(sample_data[0][0])
# Out:
# 376

# %% [markdown]
# ## Using ICA for artifact removal and then Normalizing the data using z-score normalization

# %%
def ica_norm(data):
    
    # Get the epoched EEG data from the MNE-Python data object
    sample_data = data.get_data()
    
    # Apply ICA to the epoched EEG data
    ica = ICA(n_components=sample_data.shape[1])
    ica.fit(data)
    
    # Get the ICA component labels using the ICLabel algorithm
    ica_labels = label_components(inst=data, ica=ica, method='iclabel')
    
    # Define the probability threshold for rejecting ICA components
    threshold = 0.9
    
    # Get the indices of the ICA components with probability greater than or equal to the threshold
    reject_ic, = np.where(ica_labels['y_pred_proba'] >= threshold)
    
    # Exclude the selected ICA components from the data
    ica.exclude = reject_ic
    clean_data = ica.apply(data, exclude=reject_ic)
    
    # Get the cleaned and normalized data
    clean_sample_data = clean_data.get_data()
    sample_data_z = zscore(clean_sample_data, axis=2)
    
    # Return the normalized data
    return sample_data_z

# %%
ica = ICA(n_components=sample_data.shape[1])
ica.fit(data)
# Out:
# Fitting ICA to data using 62 channels (please be patient, this may take a while)
# /tmp/ipykernel_49174/2326863931.py:2: RuntimeWarning: The epochs you passed to ICA.fit() were baseline-corrected. However, we suggest to fit ICA only on data that has been high-pass filtered, but NOT baseline-corrected.
#   ica.fit(data)
# Selecting by number: 62 components
# /tmp/ipykernel_49174/2326863931.py:2: RuntimeWarning: Using n_components=62 (resulting in n_components_=62) may lead to an unstable mixing matrix estimation because the ratio between the largest (47) and smallest (3.9e-26) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 61
#   ica.fit(data)
# Fitting ICA took 45.3s.
# <ICA | epochs decomposition, method: fastica (fit in 111 iterations on 54144 samples), 62 ICA components (62 PCA components available), channel types: eeg, no sources marked for exclusion>

# %%
ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# Out:
# /tmp/ipykernel_49174/497645255.py:1: RuntimeWarning: The provided Epochs instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# /tmp/ipykernel_49174/497645255.py:1: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')

# %%
print(set(ica_labels['labels']),'\n',ica_labels['y_pred_proba'][:5])
# Out:
# {'muscle artifact', 'heart beat', 'brain', 'eye blink', 'other'}
#  [0.98644435 0.9958284  0.79249257 0.71944517 0.84305316]

# %%
df = pd.DataFrame(ica_labels)
df.columns = ['y_pred_proba', 'labels']
display(df[df['labels'] == 'eye blink'])
display(df[df['labels'] == 'muscle artifact'])
display(df[df['labels'] == 'heart beat'])
# Out:
#     y_pred_proba     labels
# 0       0.986444  eye blink
# 1       0.995828  eye blink
# 2       0.792493  eye blink
# 6       0.764528  eye blink
# 19      0.509937  eye blink
# 55      0.463737  eye blink
#     y_pred_proba           labels
# 5       0.979858  muscle artifact
# 10      0.488747  muscle artifact
# 12      0.854460  muscle artifact
# 15      0.372697  muscle artifact
# 26      0.622525  muscle artifact
# 33      0.809227  muscle artifact
# 41      0.827641  muscle artifact
# 50      0.411092  muscle artifact
#     y_pred_proba      labels
# 37      0.325702  heart beat

# %%
threshold = 0.9

# %%
reject_ic, = np.where(ica_labels['y_pred_proba'] >= threshold)
ica.exclude = reject_ic
clean_data = ica.apply(data, exclude=reject_ic)
clean_sample_data = clean_data.get_data()
# Out:
# Applying ICA to Epochs instance
#     Transforming to ICA space (62 components)
#     Zeroing out 7 ICA components
#     Projecting back using 62 PCA components
# /tmp/ipykernel_49174/1168888695.py:3: RuntimeWarning: The data you passed to ICA.apply() was baseline-corrected. Please note that ICA can introduce DC shifts, therefore you may wish to consider baseline-correcting the cleaned data again.
#   clean_data = ica.apply(data, exclude=reject_ic)

# %%
new_data_z = ica_norm(data=data)
new_data_z[0][0]
# Out:
# Fitting ICA to data using 62 channels (please be patient, this may take a while)
# /tmp/ipykernel_49174/3680361628.py:4: RuntimeWarning: The epochs you passed to ICA.fit() were baseline-corrected. However, we suggest to fit ICA only on data that has been high-pass filtered, but NOT baseline-corrected.
#   ica.fit(data)
# Selecting by number: 62 components
# Fitting ICA took 13.0s.
# /tmp/ipykernel_49174/3680361628.py:4: RuntimeWarning: Using n_components=62 (resulting in n_components_=62) may lead to an unstable mixing matrix estimation because the ratio between the largest (62) and smallest (1.8e-13) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 1
#   ica.fit(data)
# /tmp/ipykernel_49174/3680361628.py:5: RuntimeWarning: The provided Epochs instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# /tmp/ipykernel_49174/3680361628.py:5: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# Applying ICA to Epochs instance
#     Transforming to ICA space (62 components)
#     Zeroing out 0 ICA components
#     Projecting back using 62 PCA components
# /tmp/ipykernel_49174/3680361628.py:9: RuntimeWarning: The data you passed to ICA.apply() was baseline-corrected. Please note that ICA can introduce DC shifts, therefore you may wish to consider baseline-correcting the cleaned data again.
#   clean_data = ica.apply(data, exclude=reject_ic)
# array([ 0.74538072,  0.71724916,  0.72921218,  0.73052094,  0.69513264,
#         0.72350369,  0.748382  ,  0.74094194,  0.74485029,  0.80905965,
#         0.87251924,  0.98618954,  1.02121945,  1.07676362,  1.10086838,
#         1.17081926,  1.19395588,  1.10512296,  1.02901242,  0.92872285,
#         0.87625802,  0.82056902,  0.85338095,  0.82072519,  0.80442978,
#         0.80517301,  0.85347786,  0.83293384,  0.8090222 ,  0.75753501,
#         0.72412579,  0.71919745,  0.71013457,  0.64742434,  0.63612025,
#         0.68523364,  0.70294941,  0.74036195,  0.94905301,  0.83619075,
#         0.7731858 ,  0.89070138,  0.76697444,  0.72684002,  0.72677683,
#         0.75683771,  0.79265825,  0.82977526,  0.91610938,  0.9232808 ,
#         0.84369286,  0.74300466,  0.70747464,  0.60399682,  0.58611727,
#         0.41835967,  0.40845639,  0.51349769,  0.51363638,  0.62349752,
#        -2.27297   , -2.07507116, -1.97737391, -2.25252482, -2.47498851,
#        -2.47266577, -2.08276732, -1.63607302, -2.13200517, -2.44791223,
#        -2.10775297, -2.07723047, -1.99320834, -1.97320134, -1.76739634,
#        -1.48792759, -1.76013126, -1.79473   , -1.85685268, -1.80088503,
#        -1.81798584, -1.27745184, -1.62660125, -2.04203407, -1.87721732,
#        -1.90215482, -1.98347841, -1.60266486, -1.45183667, -1.23844841,
#        -1.18751784, -1.01252351, -1.07617547, -1.02744329, -0.89396777,
#        -1.09064878, -1.40365557, -1.11300892, -0.82415801, -1.21880735,
#        -0.92977643, -0.81308275, -0.81795127, -0.76067067, -0.70321598,
#        -0.81650568, -0.66359318, -0.95060926, -0.99752359, -1.33771363,
#        -1.44623114, -1.24704579, -1.29059759, -1.12996486, -1.1365103 ,
#        -0.90744788, -0.61332955, -0.88449916, -0.67075404, -0.05237692,
#         0.18851968,  0.52101392,  0.44345566,  0.7677399 ,  0.28029027,
#        -0.24178999, -0.10714935, -0.2525305 , -0.84600931, -0.81222534,
#        -0.90781697, -0.98444494, -1.08580059, -1.04334405, -0.60909106,
#        -0.48533106])

# %%
n_epochs, n_channels, n_samples = sample_data.shape
data_2d = sample_data.reshape(n_epochs, n_channels * n_samples)
data_2d.shape
# Out:
# (144, 23312)

# %% [markdown]
# ### Loading, filtering and epoching the eeg data

# %%
# %%capture
control_epochs = [readfile(i) for i in rest_files_path]
zerob_epochs = [readfile(i) for i in zerob_files_path]
oneb_epochs = [readfile(i) for i in oneb_files_path]
twob_epochs = [readfile(i) for i in twob_files_path]

# %%
zerob_epochs[0].get_data().shape
# Out:
# (144, 62, 376)

# %% [markdown]
# #### Loading data into memory

# %%
for e in control_epochs:
    e.load_data()
    
for e in zerob_epochs:
    e.load_data()
# Out:
# Using data from preloaded Raw for 144 events and 376 original time points ...
# 0 bad epochs dropped
# Using data from preloaded Raw for 144 events and 376 original time points ...
# 0 bad epochs dropped
# Using data from preloaded Raw for 144 events and 376 original time points ...
# 0 bad epochs dropped

# %%
zerob_epochs[0].get_data().shape
# Out:
# Using data from preloaded Raw for 144 events and 376 original time points ...
# 0 bad epochs dropped
# (144, 62, 376)

# %%
control_epochs_array = [ica_norm(e) for e in control_epochs]
# Out:
# Fitting ICA to data using 62 channels (please be patient, this may take a while)
# Selecting by number: 62 components
# Fitting ICA took 321.4s.
# /home/rahul/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:123: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /tmp/ipykernel_512873/4226579625.py:8: RuntimeWarning: Using n_components=62 (resulting in n_components_=62) may lead to an unstable mixing matrix estimation because the ratio between the largest (38) and smallest (4.4e-25) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 61
#   ica.fit(data)
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided Epochs instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# Applying ICA to Epochs instance
#     Transforming to ICA space (62 components)
#     Zeroing out 14 ICA components
#     Projecting back using 62 PCA components
# Fitting ICA to data using 62 channels (please be patient, this may take a while)
# Selecting by number: 62 components
# Fitting ICA took 313.4s.
# /home/rahul/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:123: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /tmp/ipykernel_512873/4226579625.py:8: RuntimeWarning: Using n_components=62 (resulting in n_components_=62) may lead to an unstable mixing matrix estimation because the ratio between the largest (40) and smallest (3e-26) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 61
#   ica.fit(data)
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided Epochs instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# Applying ICA to Epochs instance
#     Transforming to ICA space (62 components)
#     Zeroing out 5 ICA components
#     Projecting back using 62 PCA components
# Fitting ICA to data using 62 channels (please be patient, this may take a while)
# Selecting by number: 62 components
# Fitting ICA took 150.9s.
# /tmp/ipykernel_512873/4226579625.py:8: RuntimeWarning: Using n_components=62 (resulting in n_components_=62) may lead to an unstable mixing matrix estimation because the ratio between the largest (50) and smallest (1.4e-26) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 61
#   ica.fit(data)
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided Epochs instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# Applying ICA to Epochs instance
#     Transforming to ICA space (62 components)
#     Zeroing out 11 ICA components
#     Projecting back using 62 PCA components

# %%
zerob_epochs_array = [ica_norm(e) for e in zerob_epochs]
# Out:
# Fitting ICA to data using 62 channels (please be patient, this may take a while)
# /tmp/ipykernel_512873/4226579625.py:8: RuntimeWarning: The epochs you passed to ICA.fit() were baseline-corrected. However, we suggest to fit ICA only on data that has been high-pass filtered, but NOT baseline-corrected.
#   ica.fit(data)
# Selecting by number: 62 components
# /tmp/ipykernel_512873/4226579625.py:8: RuntimeWarning: Using n_components=62 (resulting in n_components_=62) may lead to an unstable mixing matrix estimation because the ratio between the largest (47) and smallest (3.9e-26) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 61
#   ica.fit(data)
# Fitting ICA took 36.2s.
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided Epochs instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# Applying ICA to Epochs instance
#     Transforming to ICA space (62 components)
#     Zeroing out 11 ICA components
#     Projecting back using 62 PCA components
# Fitting ICA to data using 62 channels (please be patient, this may take a while)
# /tmp/ipykernel_512873/4226579625.py:21: RuntimeWarning: The data you passed to ICA.apply() was baseline-corrected. Please note that ICA can introduce DC shifts, therefore you may wish to consider baseline-correcting the cleaned data again.
#   clean_data = ica.apply(data, exclude=reject_ic)
# /tmp/ipykernel_512873/4226579625.py:8: RuntimeWarning: The epochs you passed to ICA.fit() were baseline-corrected. However, we suggest to fit ICA only on data that has been high-pass filtered, but NOT baseline-corrected.
#   ica.fit(data)
# Selecting by number: 62 components
# Fitting ICA took 48.9s.
# /tmp/ipykernel_512873/4226579625.py:8: RuntimeWarning: Using n_components=62 (resulting in n_components_=62) may lead to an unstable mixing matrix estimation because the ratio between the largest (38) and smallest (1.3e-25) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 61
#   ica.fit(data)
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided Epochs instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# Applying ICA to Epochs instance
#     Transforming to ICA space (62 components)
#     Zeroing out 19 ICA components
#     Projecting back using 62 PCA components
# Fitting ICA to data using 62 channels (please be patient, this may take a while)
# /tmp/ipykernel_512873/4226579625.py:21: RuntimeWarning: The data you passed to ICA.apply() was baseline-corrected. Please note that ICA can introduce DC shifts, therefore you may wish to consider baseline-correcting the cleaned data again.
#   clean_data = ica.apply(data, exclude=reject_ic)
# /tmp/ipykernel_512873/4226579625.py:8: RuntimeWarning: The epochs you passed to ICA.fit() were baseline-corrected. However, we suggest to fit ICA only on data that has been high-pass filtered, but NOT baseline-corrected.
#   ica.fit(data)
# Selecting by number: 62 components
# Fitting ICA took 48.0s.
# /tmp/ipykernel_512873/4226579625.py:8: RuntimeWarning: Using n_components=62 (resulting in n_components_=62) may lead to an unstable mixing matrix estimation because the ratio between the largest (25) and smallest (1.3e-24) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 61
#   ica.fit(data)
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided Epochs instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# /tmp/ipykernel_512873/4226579625.py:11: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   ica_labels = label_components(inst=data, ica=ica, method='iclabel')
# Applying ICA to Epochs instance
#     Transforming to ICA space (62 components)
#     Zeroing out 14 ICA components
#     Projecting back using 62 PCA components
# /tmp/ipykernel_512873/4226579625.py:21: RuntimeWarning: The data you passed to ICA.apply() was baseline-corrected. Please note that ICA can introduce DC shifts, therefore you may wish to consider baseline-correcting the cleaned data again.
#   clean_data = ica.apply(data, exclude=reject_ic)

# %%
zerob_epochs_array[0].shape, zerob_epochs[0].get_data().shape
# Out:
# ((144, 62, 376), (144, 62, 376))

# %% [markdown]
# ## Checking Artifact Removal Accuracy

# %%
freqs, psd_orig = signal.welch(zerob_epochs[0].get_data().mean(axis=0), fs=zerob_epochs[0].info['sfreq'])
freqs, psd_clean = signal.welch(zerob_epochs_array[0].mean(axis=0), fs=zerob_epochs[0].info['sfreq'])

x = freqs
y = np.arange(zerob_epochs_array[0].shape[1])
X, Y = np.meshgrid(x, y)
Z1 = 10 * np.log10(psd_orig)
Z2 = 10 * np.log10(psd_clean)

# fig = plt.figure(figsize=(12, 12))
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(X, Y, Z1, cmap='coolwarm', alpha=0.8)
# ax.plot_surface(X, Y, Z2, cmap='coolwarm', alpha=0.8)
# ax.set_xlabel('Frequency (Hz)')
# ax.set_ylabel('Epoch')
# ax.set_zlabel('Power Spectral Density (dB)')
# ax.set_title('Original vs. Cleaned Power Spectral Density')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6), subplot_kw={'projection': '3d'})

ax1.plot_surface(X, Y, Z1, cmap='coolwarm', alpha=0.7)
ax1.set_xlabel('Frequency (Hz)')
ax1.set_ylabel('Epoch')
ax1.set_zlabel('Power Spectral Density (dB)')
ax1.set_title('Original Power Spectral Density')

ax2.plot_surface(X, Y, Z2, cmap='coolwarm', alpha=0.8)
ax2.set_xlabel('Frequency (Hz)')
ax2.set_ylabel('Epoch')
ax2.set_zlabel('Power Spectral Density (dB)')
ax2.set_title('Cleaned Power Spectral Density')


plt.show()

# %%
control_epochs_labels = [len(i)*[0] for i in control_epochs_array]
zerob_epochs_labels = [len(i)*[0] for i in zerob_epochs_array]
oneb_epochs_labels = [len(i)*[0] for i in oneb_epochs_array]
twob_epochs_labels = [len(i)*[0] for i in twob_epochs_array]

len(control_epochs_labels), len(zerob_epochs_labels), len(oneb_epochs_labels), len(twob_epochs_labels)

# %%
data_list = control_epochs_array + zerob_epochs_array + oneb_epochs_array + twob_epochs_array
label_list = control_epochs_labels + zerob_epochs_labels + oneb_epochs_labels + twob_epochs_labels

# %%
group_list=[[i]*len(j) for i,j in enumerate(data_list)]
len(group_list)

# %%
data_array = np.vstack(data_list)
label_array = np.hstack(label_list)
group_array = np.hstack(group_list)

data_array.shape, label_array.shape, group_array.shape

# %%
'6A5571928D2222D83BC7456E4EDE055B645F044F' == '6A5571928D2222D83BC7456E4EDE055B645F044F'
# Out:
# True
